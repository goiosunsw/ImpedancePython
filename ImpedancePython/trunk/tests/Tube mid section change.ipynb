# %%
import sys
sys.path.append('..')
import ImpedanceSynthesiser as imps
import numpy as np
import matplotlib.pyplot as pl
# %matplotlib notebook

reload(imps)
# Out:
# <module 'ImpedanceSynthesiser' from '../ImpedanceSynthesiser.pyc'>

# %%
world = imps.AcousticWorld()

l0 = 1.0
lmid=.2

rad0 = .0075
rad_mid = [.003,.005,.01,.02]

ducts = []
loss=True

duct = imps.Duct(world=world,losses=loss)
duct.set_termination(imps.PerfectOpenEnd())
duct.append_element(imps.StraightDuct(length=l0,radius=rad0))
ducts.append(duct)

for rad_e in rad_mid:
    duct = imps.Duct(world=world,losses=loss)
    duct.set_termination(imps.PerfectOpenEnd())
    duct.append_element(imps.StraightDuct(length=(l0-lmid)/2,radius=rad0))
    duct.append_element(imps.StraightDuct(length=lmid,radius=rad_e))
    duct.append_element(imps.StraightDuct(length=(l0-lmid)/2,radius=rad0))
    ducts.append(duct)

duct = imps.Duct(world=world,losses=loss)
duct.set_termination(imps.PerfectOpenEnd())
duct.append_element(imps.StraightDuct(length=l0,radius=rad0))
ducts.append(duct)

# %%
fvec = np.linspace(10,500,1000)

#fig,ax=pl.subplots(2,sharex=True)

ax = None
for duct in ducts:
    if ax is None:
        ax=duct.plot_report( fmin=20, fmax=max(fvec), npoints=2000)
    else:
        duct.plot_report(ax=ax, fmin=20, fmax=max(fvec), npoints=2000)
    
ax[1].axhline((np.abs(duct.elements[0].get_characteristic_impedance())),
              lw=1,ls='--',color='r')

f=0
c=duct.speed_of_sound
while f < max(fvec):
    f+=c/(4*l0)
    ax[1].axvline(f,ls='--',lw=1)
    ax[2].axvline(f,ls='--',lw=1)
# Out:
# <img src="data:image/png;base64,...">

# %%
world = imps.AcousticWorld()

l0 = 1.0
lmid_list=[.05,.1,.2,.4]

rad0 = .0075
rad_e = 0.01


ducts = []
loss=True

duct = imps.Duct(world=world,losses=loss)
duct.set_termination(imps.PerfectOpenEnd())
duct.append_element(imps.StraightDuct(length=l0,radius=rad0))
ducts.append(duct)

for lmid in lmid_list:
    duct = imps.Duct(world=world,losses=loss)
    duct.set_termination(imps.PerfectOpenEnd())
    duct.append_element(imps.StraightDuct(length=(l0-lmid)/2,radius=rad0))
    duct.append_element(imps.StraightDuct(length=lmid,radius=rad_e))
    duct.append_element(imps.StraightDuct(length=(l0-lmid)/2,radius=rad0))
    ducts.append(duct)

# %%
fvec = np.linspace(10,500,1000)

#fig,ax=pl.subplots(2,sharex=True)

ax = None
for duct in ducts:
    if ax is None:
        ax=duct.plot_report( fmin=20, fmax=max(fvec), npoints=2000)
    else:
        duct.plot_report(ax=ax, fmin=20, fmax=max(fvec), npoints=2000)
    
ax[1].axhline((np.abs(duct.elements[0].get_characteristic_impedance())),
              lw=1,ls='--',color='r')

f=0
c=duct.speed_of_sound
while f < max(fvec):
    f+=c/(4*l0)
    ax[1].axvline(f,ls='--',lw=1)
    ax[2].axvline(f,ls='--',lw=1)
# Out:
# <img src="data:image/png;base64,...">

# %%
world = imps.AcousticWorld()

l0 = 1.0
lmid=.2

rad0 = .0075
rad_e = .015
pos_mid = [.3,.5,.7]

ducts = []
loss=True

duct = imps.Duct(world=world,losses=loss)
duct.set_termination(imps.PerfectOpenEnd())
duct.append_element(imps.StraightDuct(length=l0,radius=rad0))
ducts.append(duct)

for pos_m in pos_mid:
    duct = imps.Duct(world=world,losses=loss)
    duct.set_termination(imps.PerfectOpenEnd())
    duct.append_element(imps.StraightDuct(length=pos_m-(lmid)/2,radius=rad0))
    duct.append_element(imps.StraightDuct(length=lmid,radius=rad_e))
    duct.append_element(imps.StraightDuct(length=l0-(pos_m+(lmid)/2),radius=rad0))
    ducts.append(duct)

duct = imps.Duct(world=world,losses=loss)
duct.set_termination(imps.PerfectOpenEnd())
duct.append_element(imps.StraightDuct(length=l0,radius=rad0))
ducts.append(duct)

# %%
fvec = np.linspace(10,500,1000)

#fig,ax=pl.subplots(2,sharex=True)

ax = None
for duct in ducts:
    if ax is None:
        ax=duct.plot_report( fmin=20, fmax=max(fvec), npoints=2000)
    else:
        duct.plot_report(ax=ax, fmin=20, fmax=max(fvec), npoints=2000)
    
ax[1].axhline((np.abs(duct.elements[0].get_characteristic_impedance())),
              lw=1,ls='--',color='r')

f=0
c=duct.speed_of_sound
while f < max(fvec):
    f+=c/(4*l0)
    ax[1].axvline(f,ls='--',lw=1)
    ax[2].axvline(f,ls='--',lw=1)
# Out:
# <img src="data:image/png;base64,...">
