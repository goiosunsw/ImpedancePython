# %%
import sys
sys.path.append('..')
sys.path.append('../tests')
import ImpedanceSynthesiser as imps
import test_chaining as impstest

import matplotlib.pyplot as pl
# %matplotlib notebook

# %%
dd=impstest.random_duct(1,radii=[.008])
e0=dd.elements[0]
e0.get_propagation_coefficient(1000.)
# Out:
# (18.231125806119529-0.11153888140845514j)

# %%
dd.plot_impedance(npoints=1000)
# Out:
# <img src="data:image/png;base64,...">
# ../ImpedanceSynthesiser.py:314: RuntimeWarning: divide by zero encountered in double_scalars
#   P = np.sqrt(2)/rv
# ../ImpedanceSynthesiser.py:315: RuntimeWarning: divide by zero encountered in double_scalars
#   PQ = (self.gamma-1)*np.sqrt(2)/rt
# ../ImpedanceSynthesiser.py:316: RuntimeWarning: invalid value encountered in multiply
#   Zv = omega*rho*(P*(1.+3.*P/2.)+1j*(1.+P))
# ../ImpedanceSynthesiser.py:318: RuntimeWarning: invalid value encountered in multiply
#   (PQ*(1.-PQ/(2*(self.gamma-1.)))+1j*(1.+PQ))
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2cac763c10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f2cac6ac250>], dtype=object)

# %%
fvec=np.arange(10,5000,1)

zvec = -np.fromiter((dd.get_input_impedance_at_freq(f) for f in fvec), np.complex)

fig,ax = pl.subplots(2,sharex=True)
ax[0].plot(fvec,20*np.log10(np.abs(zvec)))
ax[1].plot(fvec,np.angle(zvec))
# Out:
# <img src="data:image/png;base64,...">

# %%
isinstance(dd,imps.Duct)
# Out:
# True

# %%
dd
